# %%
import torch
import pandas 
import numpy
import optuna
import pytorch_lightning as pl
import kagglehub

# %%
data = {
    "x1": [1, 2, 3],
    'x2': [7,4,1]
}

df = pandas.DataFrame(
    data
)
df
# Out:
#    x1  x2
# 0   1   7
# 1   2   4
# 2   3   1

# %%
torch.tensor(df.values)
# Out:
# tensor([[1, 7],
#         [2, 4],
#         [3, 1]])
